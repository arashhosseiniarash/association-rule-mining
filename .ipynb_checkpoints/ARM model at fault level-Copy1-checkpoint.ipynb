# %%
import pandas as pd

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv (r'C:\Users\arash\Desktop\association-rule-mining\dataframe-python.csv')

# %%
df
# Out:
#       SVM  Neural Networks/Deep Learining  Dimensionality Reduction  \
# 0   False                           False                     False
# 1    True                           False                     False
# 2   False                           False                     False
# 3   False                            True                     False
# 4   False                            True                     False
# ..    ...                             ...                       ...
# 77   True                           False                     False
# 78  False                           False                     False
# 79  False                            True                     False
# 80  False                           False                     False
# 81  False                           False                     False
#
#     Bayesian networks  decision tree  Hybrid  Rule based  Ensemble learning  \
# 0               False          False   False       False               True
# 1               False          False   False       False              False
# 2               False           True   False       False              False
# 3               False          False   False       False              False
# 4               False          False   False       False              False
# ..                ...            ...     ...         ...                ...
# 77              False          False   False       False              False
# 78              False          False   False       False              False
# 79              False          False   False       False              False
# 80              False          False   False        True              False
# 81              False          False    True       False              False
#
#     Regression  Clustering  ...  Temperature issue  Speed  \
# 0        False       False  ...              False   True
# 1        False       False  ...              False  False
# 2        False       False  ...              False   True
# 3        False       False  ...               True  False
# 4        False       False  ...              False   True
# ..         ...         ...  ...                ...    ...
# 77       False       False  ...              False  False
# 78       False        True  ...              False  False
# 79       False       False  ...              False  False
# 80       False       False  ...              False  False
# 81       False       False  ...              False  False
#
#     Control/[schedule issues]  Set point  Performance  Instablity  \
# 0                        True      False        False       False
# 1                       False      False        False       False
# 2                       False      False        False       False
# 3                       False       True         True       False
# 4                        True      False        False        True
# ..                        ...        ...          ...         ...
# 77                      False      False        False       False
# 78                      False      False        False       False
# 79                      False      False        False       False
# 80                      False      False        False       False
# 81                      False      False        False       False
#
#     Capacity reduction  blockage  Schedule  Sizing issue
# 0                False     False     False         False
# 1                False     False     False         False
# 2                False     False     False         False
# 3                False     False     False         False
# 4                 True      True     False         False
# ..                 ...       ...       ...           ...
# 77               False     False     False         False
# 78               False     False     False         False
# 79               False     False     False         False
# 80               False     False     False         False
# 81               False     False     False         False
#
# [82 rows x 30 columns]

# %%
# pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
print(df)
# Out:
#       SVM  Neural Networks/Deep Learining  Dimensionality Reduction  \
# 0   False                           False                     False
# 1    True                           False                     False
# 2   False                           False                     False
# 3   False                            True                     False
# 4   False                            True                     False
# ..    ...                             ...                       ...
# 77   True                           False                     False
# 78  False                           False                     False
# 79  False                            True                     False
# 80  False                           False                     False
# 81  False                           False                     False
#
#     Bayesian networks  decision tree  Hybrid  Rule based  Ensemble learning  \
# 0               False          False   False       False               True
# 1               False          False   False       False              False
# 2               False           True   False       False              False
# 3               False          False   False       False              False
# 4               False          False   False       False              False
# ..                ...            ...     ...         ...                ...
# 77              False          False   False       False              False
# 78              False          False   False       False              False
# 79              False          False   False       False              False
# 80              False          False   False        True              False
# 81              False          False    True       False              False
#
#     Regression  Clustering  ...  Temperature issue  Speed  \
# 0        False       False  ...              False   True
# 1        False       False  ...              False  False
# 2        False       False  ...              False   True
# 3        False       False  ...               True  False
# 4        False       False  ...              False   True
# ..         ...         ...  ...                ...    ...
# 77       False       False  ...              False  False
# 78       False        True  ...              False  False
# 79       False       False  ...              False  False
# 80       False       False  ...              False  False
# 81       False       False  ...              False  False
#
#     Control/[schedule issues]  Set point  Performance  Instablity  \
# 0                        True      False        False       False
# 1                       False      False        False       False
# 2                       False      False        False       False
# 3                       False       True         True       False
# 4                        True      False        False        True
# ..                        ...        ...          ...         ...
# 77                      False      False        False       False
# 78                      False      False        False       False
# 79                      False      False        False       False
# 80                      False      False        False       False
# 81                      False      False        False       False
#
#     Capacity reduction  blockage  Schedule  Sizing issue
# 0                False     False     False         False
# 1                False     False     False         False
# 2                False     False     False         False
# 3                False     False     False         False
# 4                 True      True     False         False
# ..                 ...       ...       ...           ...
# 77               False     False     False         False
# 78               False     False     False         False
# 79               False     False     False         False
# 80               False     False     False         False
# 81               False     False     False         False
#
# [82 rows x 30 columns]

# %%
frequent_itemsets_fp=fpgrowth(df, min_support=0.2, use_colnames=True)

# %%
print(frequent_itemsets_fp)
# Out:
#      support                                 itemsets
# 0   0.341463                                (Leakage)
# 1   0.231707                 (Stuck/partially closed)
# 2   0.439024                            (Limit issue)
# 3   0.378049                                   (Foul)
# 4   0.329268                          (Flow problems)
# 5   0.219512                       (Non-Condensables)
# 6   0.207317                                    (SVM)
# 7   0.268293                 (bias/drift/calibration)
# 8   0.243902                          (Leakage, Foul)
# 9   0.268293                      (Limit issue, Foul)
# 10  0.243902                    (Flow problems, Foul)
# 11  0.231707                 (Leakage, Flow problems)
# 12  0.219512             (Flow problems, Limit issue)
# 13  0.207317       (Flow problems, Limit issue, Foul)
# 14  0.219512        (Non-Condensables, Flow problems)
# 15  0.219512                 (Non-Condensables, Foul)
# 16  0.219512  (Non-Condensables, Flow problems, Foul)

# %%
rules_fp = association_rules(frequent_itemsets_fp, metric="confidence", min_threshold=0.7)

# %%
print(rules_fp)
# Out:
#                           antecedents            consequents  \
# 0                           (Leakage)                 (Foul)
# 1                              (Foul)          (Limit issue)
# 2                     (Flow problems)                 (Foul)
# 3                     (Flow problems)              (Leakage)
# 4        (Flow problems, Limit issue)                 (Foul)
# 5               (Flow problems, Foul)          (Limit issue)
# 6                 (Foul, Limit issue)        (Flow problems)
# 7                  (Non-Condensables)        (Flow problems)
# 8                  (Non-Condensables)                 (Foul)
# 9   (Non-Condensables, Flow problems)                 (Foul)
# 10           (Non-Condensables, Foul)        (Flow problems)
# 11              (Flow problems, Foul)     (Non-Condensables)
# 12                 (Non-Condensables)  (Flow problems, Foul)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.341463            0.378049  0.243902    0.714286  1.889401
# 1             0.378049            0.439024  0.268293    0.709677  1.616487
# 2             0.329268            0.378049  0.243902    0.740741  1.959379
# 3             0.329268            0.341463  0.231707    0.703704  2.060847
# 4             0.219512            0.378049  0.207317    0.944444  2.498208
# 5             0.243902            0.439024  0.207317    0.850000  1.936111
# 6             0.268293            0.329268  0.207317    0.772727  2.346801
# 7             0.219512            0.329268  0.219512    1.000000  3.037037
# 8             0.219512            0.378049  0.219512    1.000000  2.645161
# 9             0.219512            0.378049  0.219512    1.000000  2.645161
# 10            0.219512            0.329268  0.219512    1.000000  3.037037
# 11            0.243902            0.219512  0.219512    0.900000  4.100000
# 12            0.219512            0.243902  0.219512    1.000000  4.100000
#
#     leverage  conviction
# 0   0.114813    2.176829
# 1   0.102320    1.932249
# 2   0.119423    2.398955
# 3   0.119274    2.222561
# 4   0.124331   11.195122
# 5   0.100238    3.739837
# 6   0.118977    2.951220
# 7   0.147234         inf
# 8   0.136526         inf
# 9   0.136526         inf
# 10  0.147234         inf
# 11  0.165973    7.804878
# 12  0.165973         inf

# %%
rules_fp
# Out:
#                           antecedents            consequents  \
# 0                           (Leakage)                 (Foul)
# 1                              (Foul)          (Limit issue)
# 2                     (Flow problems)                 (Foul)
# 3                     (Flow problems)              (Leakage)
# 4        (Flow problems, Limit issue)                 (Foul)
# 5               (Flow problems, Foul)          (Limit issue)
# 6                 (Foul, Limit issue)        (Flow problems)
# 7                  (Non-Condensables)        (Flow problems)
# 8                  (Non-Condensables)                 (Foul)
# 9   (Non-Condensables, Flow problems)                 (Foul)
# 10           (Non-Condensables, Foul)        (Flow problems)
# 11              (Flow problems, Foul)     (Non-Condensables)
# 12                 (Non-Condensables)  (Flow problems, Foul)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.341463            0.378049  0.243902    0.714286  1.889401
# 1             0.378049            0.439024  0.268293    0.709677  1.616487
# 2             0.329268            0.378049  0.243902    0.740741  1.959379
# 3             0.329268            0.341463  0.231707    0.703704  2.060847
# 4             0.219512            0.378049  0.207317    0.944444  2.498208
# 5             0.243902            0.439024  0.207317    0.850000  1.936111
# 6             0.268293            0.329268  0.207317    0.772727  2.346801
# 7             0.219512            0.329268  0.219512    1.000000  3.037037
# 8             0.219512            0.378049  0.219512    1.000000  2.645161
# 9             0.219512            0.378049  0.219512    1.000000  2.645161
# 10            0.219512            0.329268  0.219512    1.000000  3.037037
# 11            0.243902            0.219512  0.219512    0.900000  4.100000
# 12            0.219512            0.243902  0.219512    1.000000  4.100000
#
#     leverage  conviction
# 0   0.114813    2.176829
# 1   0.102320    1.932249
# 2   0.119423    2.398955
# 3   0.119274    2.222561
# 4   0.124331   11.195122
# 5   0.100238    3.739837
# 6   0.118977    2.951220
# 7   0.147234         inf
# 8   0.136526         inf
# 9   0.136526         inf
# 10  0.147234         inf
# 11  0.165973    7.804878
# 12  0.165973         inf
